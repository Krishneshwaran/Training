# %% [markdown]
#  # Task 2: Data Structure Basics

# %%
list=[1,2,3]
list.append(4)

set={2,4,6}

tuple=(1,3,5)

dictionary={"a":1, "b":2}
dictionary["c"]=3

print("List with appended fourth integer:\n",list)
print("Initialized a set with 3 unique even numbers\n", set)
print("Initialized a tuple with 3 odd numbers.\n", tuple)
print("Created a dictionary with 3 key-value pairs\n", dictionary)
# Out:
# List with appended fourth integer:
#  [1, 2, 3, 4]
# Initialized a set with 3 unique even numbers
#  {2, 4, 6}
# Initialized a tuple with 3 odd numbers.
#  (1, 3, 5)
# Created a dictionary with 3 key-value pairs
#  {'a': 1, 'b': 2, 'c': 3}
