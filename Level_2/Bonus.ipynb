# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\vatch\Downloads\titanic\tested.csv")
correlation_matrix=data.corr(numeric_only=True)
sns.heatmap(correlation_matrix,cmap="coolwarm") #correlation_matrix, annot=True, cmap="coolwarm", fmt='.2f', linewidths=0.5)
plt.title("Heatmap - Titanic dataset")
plt.show()
