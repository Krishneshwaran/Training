# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y,c='b',marker='o',linestyle='-',linewidth=1,markersize=5,label="Line Chart")
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('simple plot')
plt.legend()
plt.show()
